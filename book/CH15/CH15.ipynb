# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

import time

from torch import optim
from torch.nn import MSELoss, L1Loss
from torch.utils.data import DataLoader, TensorDataset

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(torch.__version__)
# Out:
# 2.12.0

# %%
torch.manual_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('../data/train.csv', index_col=0)
val_df = pd.read_csv('../data/val.csv', index_col=0)
test_df = pd.read_csv('../data/test.csv', index_col=0)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (12285, 5) (3510, 5) (1756, 5)

# %%
# 시계열 데이터를 입력(Input)과 정답(Label)으로 나누어
# PyTorch DataLoader를 생성하는 클래스
class DataWindow():
    def __init__(self, input_width, label_width, shift,
                 train_df=train_df, val_df=val_df, test_df=test_df,
                 label_columns=None):

        # 학습 / 검증 / 테스트 데이터
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df

        # 예측할 Label 컬럼
        self.label_columns = label_columns

        # Label 컬럼 이름 -> index
        if label_columns is not None:
            self.label_columns_indices = {
                name: i for i, name in enumerate(label_columns)
            }

        # 전체 컬럼 이름 -> index
        self.column_indices = {
            name: i for i, name in enumerate(train_df.columns)
        }

        # 입력(Input) 길이
        self.input_width = input_width

        # 예측(Label) 길이
        self.label_width = label_width

        # 입력(Input)의 시작 시점과
        # Label의 시작 시점 사이의 시간 간격
        #
        # 예)
        #
        # input_width = 6
        # label_width = 6
        # shift = 1
        #
        # Window : [0 1 2 3 4 5 6]
        # Input  : [0 1 2 3 4 5]
        # Label  :  [1 2 3 4 5 6]
        self.shift = shift

        # 하나의 Window 전체 길이
        #
        # total_window_size
        # = input_width + shift
        #
        # 예)
        #
        # Window : [0 1 2 3 4 5 6]
        self.total_window_size = input_width + shift

        # Input 구간 지정
        #
        # slice(0, input_width)
        #
        # Window : [0 1 2 3 4 5 6]
        # Input  : [0 1 2 3 4 5]
        self.input_slice = slice(0, input_width)

        # Input의 시간 index
        #
        # np.arange(7)
        # -> [0 1 2 3 4 5 6]
        #
        # Input
        # -> [0 1 2 3 4 5]
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]

        # Label 시작 위치
        #
        # label_start
        # = total_window_size - label_width
        #
        # = 7 - 6
        # = 1
        #
        # Window : [0 1 2 3 4 5 6]
        # Label  :  [1 2 3 4 5 6]
        self.label_start = self.total_window_size - self.label_width

        # Label 구간
        #
        # slice(1, None)
        #
        # None은 끝까지를 의미
        #
        # Window : [0 1 2 3 4 5 6]
        # Label  :  [1 2 3 4 5 6]
        self.labels_slice = slice(self.label_start, None)

        # Label의 시간 index
        #
        # np.arange(7)
        # -> [0 1 2 3 4 5 6]
        #
        # Label
        # -> [1 2 3 4 5 6]
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

    # 하나의 Window를 Input과 Label로 분리
    def _split_to_inputs_labels(self, features):

        # features
        # = [batch, total_window_size, feature]

        # Input 선택
        #
        # -> [batch, input_width, feature]
        inputs = features[:, self.input_slice, :]

        # Label 선택
        #
        # -> [batch, label_width, feature]
        labels = features[:, self.labels_slice, :]

        # 특정 컬럼만 Label로 사용할 경우
        if self.label_columns is not None:

            # labels[:, :, self.column_indices[name]]
            # = 지정한 컬럼 하나 선택
            #
            # -> [batch, label_width]
            #
            # np.stack(..., axis=-1)
            # = 선택한 컬럼들을 마지막(feature) 차원으로 다시 묶음
            #
            # 예)
            #
            # traffic -> [batch, label_width]
            # temp    -> [batch, label_width]
            #
            # ->
            #
            # [batch, label_width, 2]
            labels = np.stack(
                [
                    labels[:, :, self.column_indices[name]]
                    for name in self.label_columns
                ],
                axis=-1
            )

        return inputs, labels

    # Input / Label / Prediction 시각화
    def plot(self, model=None, plot_col='traffic_volume', max_subplots=3):

        # 예시 Batch 가져오기
        inputs, labels = self.sample_batch

        # PyTorch Tensor이면 NumPy 배열로 변환
        if isinstance(inputs, torch.Tensor):
            inputs = inputs.numpy()

        if isinstance(labels, torch.Tensor):
            labels = labels.numpy()

        plt.figure(figsize=(12, 8))

        plot_col_index = self.column_indices[plot_col]

        max_n = min(max_subplots, len(inputs))

        for n in range(max_n):

            plt.subplot(3, 1, n + 1)

            plt.ylabel(f'{plot_col} [scaled]')

            # 입력 시계열
            plt.plot(
                self.input_indices,
                inputs[n, :, plot_col_index],
                label='Inputs',
                marker='.',
                zorder=-10
            )

            if self.label_columns:
                label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
                label_col_index = plot_col_index

            if label_col_index is None:
                continue

            # 실제 Label
            plt.scatter(
                self.label_indices,
                labels[n, :, label_col_index],
                edgecolors='k',
                marker='s',
                label='Labels',
                c='green',
                s=64
            )

            # 모델이 있으면 예측 결과도 출력
            if model is not None:

                model.eval()

                with torch.no_grad():

                    predictions = model(
                        torch.tensor(
                            inputs,
                            dtype=torch.float32
                        )
                    )

                predictions = predictions.numpy()

                plt.scatter(
                    self.label_indices,
                    predictions[n, :, label_col_index],
                    marker='X',
                    edgecolors='k',
                    label='Predictions',
                    c='red',
                    s=64
                )

            if n == 0:
                plt.legend()

        plt.xlabel('Time (h)')

    # DataFrame을 PyTorch DataLoader로 변환
    def make_dataset(self, data):

        # DataFrame -> NumPy 배열
        data = np.array(data, dtype=np.float32)

        # 생성 가능한 Window 개수
        #
        # 예)
        #
        # 데이터 길이 = 100
        # Window 길이 = 7
        #
        # Window 개수 = 94
        n_samples = len(data) - self.total_window_size + 1

        # Sliding Window 생성
        #
        # [0 1 2 3 4 5 6]
        # [1 2 3 4 5 6 7]
        # [2 3 4 5 6 7 8]
        # ...
        #
        # ->
        #
        # features
        # = [window 개수, total_window_size, feature]
        features = np.stack(
            [
                data[i:i + self.total_window_size]
                for i in range(n_samples)
            ],
            axis=0
        )

        # 각 Window를 Input / Label로 분리
        inputs, labels = self._split_to_inputs_labels(features)

        # NumPy -> PyTorch Tensor 변환
        #
        # TensorDataset은
        #
        # (input1, label1)
        # (input2, label2)
        # ...
        #
        # 형태로 데이터를 저장하는 Dataset 클래스
        dataset = TensorDataset(
            torch.tensor(inputs, dtype=torch.float32),
            torch.tensor(labels, dtype=torch.float32),
        )

        # DataLoader 생성
        #
        # TensorDataset으로부터
        #
        # - Mini-batch 생성
        # - Shuffle
        # - 반복(iteration)
        #
        # 기능을 제공한다.
        return DataLoader(
            dataset,
            batch_size=32,
            shuffle=True
        )

    # 학습 DataLoader
    @property
    def train(self):
        return self.make_dataset(self.train_df)

    # 검증 DataLoader
    @property
    def val(self):
        return self.make_dataset(self.val_df)

    # 테스트 DataLoader
    @property
    def test(self):
        return self.make_dataset(self.test_df)

    # 시각화를 위한 예시 Batch 반환
    @property
    def sample_batch(self):

        # 이미 저장된 Batch가 있으면 재사용
        result = getattr(self, '_sample_batch', None)

        # 없으면 학습 DataLoader에서 첫 번째 Batch를 가져와 저장
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result

        return result

# %%
# 모델 학습 함수
#
# Early Stopping을 적용하여 모델을 학습하고
# 학습 과정(loss, MAE)을 반환
def compile_and_fit(model, window, patience=3, max_epochs=50, lr=0.001):

    # Adam Optimizer 생성
    optimizer = optim.Adam(model.parameters(), lr=lr)

    # Loss 함수(MSE)
    mse_fn = MSELoss()

    # 평가 지표(MAE)
    #
    # reduction='sum'
    # -> Batch 전체 오차 합 계산
    mae_fn = L1Loss(reduction='sum')

    # 가장 작은 Validation Loss
    best_val_loss = float('inf')

    # Early Stopping을 위한 카운터
    patience_counter = 0

    # 학습 기록 저장
    history = {
        'loss': [],
        'val_loss': [],
        'mean_absolute_error': [],
        'val_mean_absolute_error': [],
    }

    def _format_step_time(epoch_time, n_steps):
        if n_steps == 0:
            return '0s 0us/step'
        per_step = epoch_time / n_steps
        if epoch_time >= 1.0:
            return f'{epoch_time:.0f}s {per_step * 1000:.0f}ms/step'
        return f'0s {per_step * 1e6:.0f}us/step'

    # 최대 Epoch만큼 반복
    for epoch in range(max_epochs):
        epoch_start = time.perf_counter()

        # ==========================
        # Train
        # ==========================
        model.train()

        train_loss = 0.0
        train_mae = 0.0
        train_n = 0

        train_loader = window.train
        n_batches = len(train_loader)

        # 모든 Mini-batch 학습
        for inputs, labels in train_loader:

            # Gradient 초기화
            optimizer.zero_grad()

            # 모델 예측
            preds = model(inputs)

            # Loss 계산
            loss = mse_fn(preds, labels)

            # 역전파
            loss.backward()

            # 가중치 업데이트
            optimizer.step()

            batch_size = labels.size(0)

            # Loss 누적
            #
            # loss.item()은 Batch 평균 Loss이므로
            # Batch 크기를 곱해 전체 Loss로 변환
            train_loss += loss.item() * batch_size

            # MAE 누적
            train_mae += mae_fn(preds, labels).item()

            # 전체 데이터 개수 누적
            train_n += batch_size

        # ==========================
        # Validation
        # ==========================
        model.eval()

        val_loss = 0.0
        val_mae = 0.0
        val_n = 0

        # Gradient 계산 없이 평가
        with torch.no_grad():

            for inputs, labels in window.val:

                # 모델 예측
                preds = model(inputs)

                batch_size = labels.size(0)

                # Validation Loss 누적
                val_loss += mse_fn(preds, labels).item() * batch_size

                # Validation MAE 누적
                val_mae += mae_fn(preds, labels).item()

                # 전체 데이터 개수 누적
                val_n += batch_size

        # Epoch 평균 Loss 계산
        train_loss /= train_n
        val_loss /= val_n

        # Epoch 평균 MAE 계산
        train_mae /= train_n
        val_mae /= val_n

        # 학습 기록 저장
        history['loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['mean_absolute_error'].append(train_mae)
        history['val_mean_absolute_error'].append(val_mae)

        epoch_time = time.perf_counter() - epoch_start
        time_str = _format_step_time(epoch_time, n_batches)

        print(f'Epoch {epoch + 1}/{max_epochs}')
        print(
            f'{n_batches}/{n_batches} [==============================] - {time_str} - '
            f'loss: {train_loss:.4f} - mean_absolute_error: {train_mae:.4f} - '
            f'val_loss: {val_loss:.4f} - val_mean_absolute_error: {val_mae:.4f}'
        )

        # Validation Loss가 감소하면 최고 성능 갱신
        if val_loss < best_val_loss:

            best_val_loss = val_loss

            # Early Stopping 카운터 초기화
            patience_counter = 0

        else:

            # Validation Loss가 감소하지 않음
            patience_counter += 1

            # patience Epoch 동안 개선되지 않으면 학습 종료
            if patience_counter >= patience:
                break

    # 학습 과정 반환
    return history

# %%
def evaluate_model(model, data_loader):
    model.eval()
    mse_fn = MSELoss(reduction='sum')
    mae_fn = L1Loss(reduction='sum')
    total_mse, total_mae, n_elements = 0.0, 0.0, 0
    with torch.no_grad():
        for inputs, labels in data_loader:
            preds = model(inputs)
            total_mse += mse_fn(preds, labels).item()
            total_mae += mae_fn(preds, labels).item()
            n_elements += labels.numel()
    return [total_mse / n_elements, total_mae / n_elements]

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size=32, output_size=1):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.dense = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x, _ = self.lstm(x)
        return self.dense(x)

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### Single-step model

# %%
single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['traffic_volume']) 
wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['traffic_volume'])

# %%
# Values obtained from chapter 14

mae_val = [0.083, 0.068, 0.029]
mae_test = [0.081, 0.065, 0.029]

# %%
n_features = len(train_df.columns)

lstm_model = LSTMModel(n_features, output_size=1)

history = compile_and_fit(lstm_model, wide_window)

val_performance = {}
performance = {}

val_performance['LSTM'] = evaluate_model(lstm_model, wide_window.val)
performance['LSTM'] = evaluate_model(lstm_model, wide_window.test)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 0s 1971us/step - loss: 0.0271 - mean_absolute_error: 2.8496 - val_loss: 0.0100 - val_mean_absolute_error: 1.7051
# Epoch 2/50
# 384/384 [==============================] - 0s 1933us/step - loss: 0.0066 - mean_absolute_error: 1.3831 - val_loss: 0.0043 - val_mean_absolute_error: 1.1302
# Epoch 3/50
# 384/384 [==============================] - 0s 1922us/step - loss: 0.0040 - mean_absolute_error: 1.0629 - val_loss: 0.0033 - val_mean_absolute_error: 0.9578
# Epoch 4/50
# 384/384 [==============================] - 0s 1930us/step - loss: 0.0034 - mean_absolute_error: 0.9608 - val_loss: 0.0029 - val_mean_absolute_error: 0.8960
# Epoch 5/50
# 384/384 [==============================] - 0s 1920us/step - loss: 0.0030 - mean_absolute_error: 0.8939 - val_loss: 0.0026 - val_mean_absolute_error: 0.8381
# Epoch 6/50
# 384/384 [==============================] - 0s 1927us/step - loss: 0.0028 - mean_absolute_error: 0.8511 - val_loss: 0.0024 - val_mean_absolute_error: 0.8116
# Epoch 7/50
# 384/384 [==============================] - 0s 1917us/step - loss: 0.0026 - mean_absolute_error: 0.8267 - val_loss: 0.0022 - val_mean_absolute_error: 0.7493
# Epoch 8/50
# 384/384 [==============================] - 0s 1922us/step - loss: 0.0025 - mean_absolute_error: 0.8048 - val_loss: 0.0022 - val_mean_absolute_error: 0.7621
# Epoch 9/50
# 384/384 [==============================] - 0s 1924us/step - loss: 0.0025 - mean_absolute_error: 0.7893 - val_loss: 0.0021 - val_mean_absolute_error: 0.7294
# Epoch 10/50
# 384/384 [==============================] - 0s 1929us/step - loss: 0.0024 - mean_absolute_error: 0.7772 - val_loss: 0.0020 - val_mean_absolute_error: 0.7211
# Epoch 11/50
# 384/384 [==============================] - 0s 1923us/step - loss: 0.0023 - mean_absolute_error: 0.7670 - val_loss: 0.0020 - val_mean_absolute_error: 0.7228
# Epoch 12/50
# 384/384 [==============================] - 0s 1920us/step - loss: 0.0023 - mean_absolute_error: 0.7579 - val_loss: 0.0019 - val_mean_absolute_error: 0.7097
# Epoch 13/50
# 384/384 [==============================] - 0s 1913us/step - loss: 0.0022 - mean_absolute_error: 0.7463 - val_loss: 0.0019 - val_mean_absolute_error: 0.6987
# Epoch 14/50
# 384/384 [==============================] - 0s 2066us/step - loss: 0.0022 - mean_absolute_error: 0.7383 - val_loss: 0.0018 - val_mean_absolute_error: 0.6907
# Epoch 15/50
# 384/384 [==============================] - 0s 1921us/step - loss: 0.0021 - mean_absolute_error: 0.7306 - val_loss: 0.0019 - val_mean_absolute_error: 0.7314
# Epoch 16/50
# 384/384 [==============================] - 0s 1919us/step - loss: 0.0021 - mean_absolute_error: 0.7223 - val_loss: 0.0018 - val_mean_absolute_error: 0.6840
# Epoch 17/50
# 384/384 [==============================] - 0s 1925us/step - loss: 0.0021 - mean_absolute_error: 0.7165 - val_loss: 0.0017 - val_mean_absolute_error: 0.6548
# Epoch 18/50
# 384/384 [==============================] - 0s 1953us/step - loss: 0.0020 - mean_absolute_error: 0.7099 - val_loss: 0.0017 - val_mean_absolute_error: 0.6833
# Epoch 19/50
# 384/384 [==============================] - 0s 1931us/step - loss: 0.0020 - mean_absolute_error: 0.7039 - val_loss: 0.0016 - val_mean_absolute_error: 0.6575
# Epoch 20/50
# 384/384 [==============================] - 0s 1943us/step - loss: 0.0020 - mean_absolute_error: 0.6989 - val_loss: 0.0017 - val_mean_absolute_error: 0.6700
# Epoch 21/50
# 384/384 [==============================] - 0s 1922us/step - loss: 0.0020 - mean_absolute_error: 0.6942 - val_loss: 0.0017 - val_mean_absolute_error: 0.6796
# Epoch 22/50
# 384/384 [==============================] - 0s 1924us/step - loss: 0.0019 - mean_absolute_error: 0.6921 - val_loss: 0.0016 - val_mean_absolute_error: 0.6406
# Epoch 23/50
# 384/384 [==============================] - 0s 1922us/step - loss: 0.0019 - mean_absolute_error: 0.6845 - val_loss: 0.0016 - val_mean_absolute_error: 0.6454
# Epoch 24/50
# 384/384 [==============================] - 0s 1918us/step - loss: 0.0019 - mean_absolute_error: 0.6828 - val_loss: 0.0016 - val_mean_absolute_error: 0.6425
# Epoch 25/50
# 384/384 [==============================] - 0s 1938us/step - loss: 0.0019 - mean_absolute_error: 0.6779 - val_loss: 0.0016 - val_mean_absolute_error: 0.6369
# Epoch 26/50
# 384/384 [==============================] - 0s 1922us/step - loss: 0.0019 - mean_absolute_error: 0.6739 - val_loss: 0.0016 - val_mean_absolute_error: 0.6403
# Epoch 27/50
# 384/384 [==============================] - 0s 1926us/step - loss: 0.0018 - mean_absolute_error: 0.6717 - val_loss: 0.0017 - val_mean_absolute_error: 0.6748
# Epoch 28/50
# 384/384 [==============================] - 0s 1922us/step - loss: 0.0018 - mean_absolute_error: 0.6698 - val_loss: 0.0015 - val_mean_absolute_error: 0.6430
# Epoch 29/50
# 384/384 [==============================] - 0s 1922us/step - loss: 0.0018 - mean_absolute_error: 0.6675 - val_loss: 0.0016 - val_mean_absolute_error: 0.6443
# Epoch 30/50
# 384/384 [==============================] - 0s 1947us/step - loss: 0.0018 - mean_absolute_error: 0.6663 - val_loss: 0.0015 - val_mean_absolute_error: 0.6206
# Epoch 31/50
# 384/384 [==============================] - 0s 1911us/step - loss: 0.0018 - mean_absolute_error: 0.6621 - val_loss: 0.0015 - val_mean_absolute_error: 0.6568
# Epoch 32/50
# 384/384 [==============================] - 0s 1945us/step - loss: 0.0018 - mean_absolute_error: 0.6610 - val_loss: 0.0016 - val_mean_absolute_error: 0.6441
# Epoch 33/50
# 384/384 [==============================] - 0s 1934us/step - loss: 0.0018 - mean_absolute_error: 0.6584 - val_loss: 0.0015 - val_mean_absolute_error: 0.6248
# Epoch 34/50
# 384/384 [==============================] - 0s 1914us/step - loss: 0.0017 - mean_absolute_error: 0.6552 - val_loss: 0.0015 - val_mean_absolute_error: 0.6249
# Epoch 35/50
# 384/384 [==============================] - 0s 1940us/step - loss: 0.0017 - mean_absolute_error: 0.6543 - val_loss: 0.0015 - val_mean_absolute_error: 0.6290
# Epoch 36/50
# 384/384 [==============================] - 0s 1924us/step - loss: 0.0017 - mean_absolute_error: 0.6497 - val_loss: 0.0015 - val_mean_absolute_error: 0.6633
# Epoch 37/50
# 384/384 [==============================] - 0s 1926us/step - loss: 0.0017 - mean_absolute_error: 0.6495 - val_loss: 0.0014 - val_mean_absolute_error: 0.5995
# Epoch 38/50
# 384/384 [==============================] - 0s 1957us/step - loss: 0.0017 - mean_absolute_error: 0.6475 - val_loss: 0.0014 - val_mean_absolute_error: 0.6104
# Epoch 39/50
# 384/384 [==============================] - 0s 1924us/step - loss: 0.0017 - mean_absolute_error: 0.6433 - val_loss: 0.0014 - val_mean_absolute_error: 0.6203
# Epoch 40/50
# 384/384 [==============================] - 0s 1929us/step - loss: 0.0017 - mean_absolute_error: 0.6405 - val_loss: 0.0014 - val_mean_absolute_error: 0.6093

# %%
wide_window.plot(lstm_model)

# %%
mae_val.append(val_performance['LSTM'][1])
mae_test.append(performance['LSTM'][1])

x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# ### Multi-step model

# %%
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['traffic_volume'])

# %%
# Values obtained from chapter 14

ms_mae_val = [0.309, 0.082, 0.088, 0.074]
ms_mae_test = [0.302, 0.068, 0.077, 0.059]

# %%
ms_lstm_model = LSTMModel(n_features, output_size=1)

history = compile_and_fit(ms_lstm_model, multi_window)

ms_val_performance = {}
ms_performance = {}

ms_val_performance['LSTM'] = evaluate_model(ms_lstm_model, multi_window.val)
ms_performance['LSTM'] = evaluate_model(ms_lstm_model, multi_window.test)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 0s 1933us/step - loss: 0.0459 - mean_absolute_error: 3.6184 - val_loss: 0.0221 - val_mean_absolute_error: 2.5589
# Epoch 2/50
# 383/383 [==============================] - 0s 1934us/step - loss: 0.0172 - mean_absolute_error: 2.2283 - val_loss: 0.0174 - val_mean_absolute_error: 2.1575
# Epoch 3/50
# 383/383 [==============================] - 0s 1932us/step - loss: 0.0151 - mean_absolute_error: 2.0053 - val_loss: 0.0167 - val_mean_absolute_error: 2.0919
# Epoch 4/50
# 383/383 [==============================] - 0s 1926us/step - loss: 0.0146 - mean_absolute_error: 1.9434 - val_loss: 0.0164 - val_mean_absolute_error: 1.9908
# Epoch 5/50
# 383/383 [==============================] - 0s 1929us/step - loss: 0.0142 - mean_absolute_error: 1.9047 - val_loss: 0.0157 - val_mean_absolute_error: 1.9776
# Epoch 6/50
# 383/383 [==============================] - 0s 1961us/step - loss: 0.0137 - mean_absolute_error: 1.8689 - val_loss: 0.0150 - val_mean_absolute_error: 1.9283
# Epoch 7/50
# 383/383 [==============================] - 0s 2118us/step - loss: 0.0133 - mean_absolute_error: 1.8258 - val_loss: 0.0146 - val_mean_absolute_error: 1.9079
# Epoch 8/50
# 383/383 [==============================] - 0s 2169us/step - loss: 0.0131 - mean_absolute_error: 1.8027 - val_loss: 0.0146 - val_mean_absolute_error: 1.8440
# Epoch 9/50
# 383/383 [==============================] - 0s 2147us/step - loss: 0.0128 - mean_absolute_error: 1.7736 - val_loss: 0.0141 - val_mean_absolute_error: 1.8403
# Epoch 10/50
# 383/383 [==============================] - 0s 2138us/step - loss: 0.0127 - mean_absolute_error: 1.7731 - val_loss: 0.0144 - val_mean_absolute_error: 1.8248
# Epoch 11/50
# 383/383 [==============================] - 0s 2108us/step - loss: 0.0125 - mean_absolute_error: 1.7515 - val_loss: 0.0140 - val_mean_absolute_error: 1.9109
# Epoch 12/50
# 383/383 [==============================] - 0s 2039us/step - loss: 0.0123 - mean_absolute_error: 1.7347 - val_loss: 0.0138 - val_mean_absolute_error: 1.8607
# Epoch 13/50
# 383/383 [==============================] - 0s 1933us/step - loss: 0.0123 - mean_absolute_error: 1.7272 - val_loss: 0.0137 - val_mean_absolute_error: 1.7618
# Epoch 14/50
# 383/383 [==============================] - 0s 1933us/step - loss: 0.0121 - mean_absolute_error: 1.7138 - val_loss: 0.0138 - val_mean_absolute_error: 1.7955
# Epoch 15/50
# 383/383 [==============================] - 0s 1947us/step - loss: 0.0119 - mean_absolute_error: 1.6962 - val_loss: 0.0135 - val_mean_absolute_error: 1.8734
# Epoch 16/50
# 383/383 [==============================] - 0s 1967us/step - loss: 0.0116 - mean_absolute_error: 1.6786 - val_loss: 0.0130 - val_mean_absolute_error: 1.7566
# Epoch 17/50
# 383/383 [==============================] - 0s 1971us/step - loss: 0.0113 - mean_absolute_error: 1.6491 - val_loss: 0.0125 - val_mean_absolute_error: 1.6818
# Epoch 18/50
# 383/383 [==============================] - 0s 1956us/step - loss: 0.0110 - mean_absolute_error: 1.6222 - val_loss: 0.0123 - val_mean_absolute_error: 1.7034
# Epoch 19/50
# 383/383 [==============================] - 0s 1985us/step - loss: 0.0108 - mean_absolute_error: 1.6064 - val_loss: 0.0122 - val_mean_absolute_error: 1.6770
# Epoch 20/50
# 383/383 [==============================] - 0s 1925us/step - loss: 0.0107 - mean_absolute_error: 1.5884 - val_loss: 0.0123 - val_mean_absolute_error: 1.7133
# Epoch 21/50
# 383/383 [==============================] - 0s 1931us/step - loss: 0.0106 - mean_absolute_error: 1.5789 - val_loss: 0.0119 - val_mean_absolute_error: 1.6292
# Epoch 22/50
# 383/383 [==============================] - 0s 1945us/step - loss: 0.0104 - mean_absolute_error: 1.5624 - val_loss: 0.0119 - val_mean_absolute_error: 1.6444
# Epoch 23/50
# 383/383 [==============================] - 0s 1937us/step - loss: 0.0104 - mean_absolute_error: 1.5607 - val_loss: 0.0117 - val_mean_absolute_error: 1.6550
# Epoch 24/50
# 383/383 [==============================] - 0s 1943us/step - loss: 0.0103 - mean_absolute_error: 1.5506 - val_loss: 0.0115 - val_mean_absolute_error: 1.5985
# Epoch 25/50
# 383/383 [==============================] - 0s 1915us/step - loss: 0.0102 - mean_absolute_error: 1.5386 - val_loss: 0.0118 - val_mean_absolute_error: 1.6035
# Epoch 26/50
# 383/383 [==============================] - 0s 1932us/step - loss: 0.0101 - mean_absolute_error: 1.5391 - val_loss: 0.0118 - val_mean_absolute_error: 1.6674
# Epoch 27/50
# 383/383 [==============================] - 0s 1929us/step - loss: 0.0101 - mean_absolute_error: 1.5301 - val_loss: 0.0115 - val_mean_absolute_error: 1.6074

# %%
multi_window.plot(ms_lstm_model)

# %%
ms_mae_val.append(ms_val_performance['LSTM'][1])
ms_mae_test.append(ms_performance['LSTM'][1])

x = np.arange(5)

labels = ['Baseline - Last', 'Baseline - Repeat', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# ### Multi-output model

# %%
mo_single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['temp','traffic_volume']) 
mo_wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['temp','traffic_volume'])

# %%
# Values from chapter 14

mo_mae_val = [0.048, 0.038, 0.022]
mo_mae_test = [0.047, 0.037, 0.019]

# %%
mo_lstm_model = LSTMModel(n_features, output_size=2)

history = compile_and_fit(mo_lstm_model, mo_wide_window)

mo_val_performance = {}
mo_performance = {}

mo_val_performance['LSTM'] = evaluate_model(mo_lstm_model, mo_wide_window.val)
mo_performance['LSTM'] = evaluate_model(mo_lstm_model, mo_wide_window.test)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 0s 1987us/step - loss: 0.0363 - mean_absolute_error: 6.2085 - val_loss: 0.0113 - val_mean_absolute_error: 3.3903
# Epoch 2/50
# 384/384 [==============================] - 0s 1924us/step - loss: 0.0068 - mean_absolute_error: 2.5845 - val_loss: 0.0046 - val_mean_absolute_error: 2.1082
# Epoch 3/50
# 384/384 [==============================] - 0s 1948us/step - loss: 0.0037 - mean_absolute_error: 1.8642 - val_loss: 0.0029 - val_mean_absolute_error: 1.6751
# Epoch 4/50
# 384/384 [==============================] - 0s 1934us/step - loss: 0.0029 - mean_absolute_error: 1.6014 - val_loss: 0.0024 - val_mean_absolute_error: 1.5037
# Epoch 5/50
# 384/384 [==============================] - 0s 1935us/step - loss: 0.0025 - mean_absolute_error: 1.4714 - val_loss: 0.0021 - val_mean_absolute_error: 1.3673
# Epoch 6/50
# 384/384 [==============================] - 0s 1937us/step - loss: 0.0023 - mean_absolute_error: 1.4004 - val_loss: 0.0019 - val_mean_absolute_error: 1.3019
# Epoch 7/50
# 384/384 [==============================] - 0s 1960us/step - loss: 0.0022 - mean_absolute_error: 1.3465 - val_loss: 0.0018 - val_mean_absolute_error: 1.2766
# Epoch 8/50
# 384/384 [==============================] - 0s 1945us/step - loss: 0.0021 - mean_absolute_error: 1.3006 - val_loss: 0.0016 - val_mean_absolute_error: 1.2249
# Epoch 9/50
# 384/384 [==============================] - 0s 1940us/step - loss: 0.0019 - mean_absolute_error: 1.2518 - val_loss: 0.0015 - val_mean_absolute_error: 1.1767
# Epoch 10/50
# 384/384 [==============================] - 0s 1940us/step - loss: 0.0018 - mean_absolute_error: 1.2008 - val_loss: 0.0015 - val_mean_absolute_error: 1.1624
# Epoch 11/50
# 384/384 [==============================] - 0s 1927us/step - loss: 0.0017 - mean_absolute_error: 1.1625 - val_loss: 0.0014 - val_mean_absolute_error: 1.1202
# Epoch 12/50
# 384/384 [==============================] - 0s 1936us/step - loss: 0.0017 - mean_absolute_error: 1.1395 - val_loss: 0.0013 - val_mean_absolute_error: 1.1046
# Epoch 13/50
# 384/384 [==============================] - 0s 1935us/step - loss: 0.0016 - mean_absolute_error: 1.1188 - val_loss: 0.0013 - val_mean_absolute_error: 1.0732
# Epoch 14/50
# 384/384 [==============================] - 0s 1916us/step - loss: 0.0016 - mean_absolute_error: 1.1052 - val_loss: 0.0012 - val_mean_absolute_error: 1.0395
# Epoch 15/50
# 384/384 [==============================] - 0s 1927us/step - loss: 0.0015 - mean_absolute_error: 1.0931 - val_loss: 0.0012 - val_mean_absolute_error: 1.0361
# Epoch 16/50
# 384/384 [==============================] - 0s 1914us/step - loss: 0.0015 - mean_absolute_error: 1.0788 - val_loss: 0.0012 - val_mean_absolute_error: 1.0235
# Epoch 17/50
# 384/384 [==============================] - 0s 1938us/step - loss: 0.0015 - mean_absolute_error: 1.0706 - val_loss: 0.0012 - val_mean_absolute_error: 1.0617
# Epoch 18/50
# 384/384 [==============================] - 0s 1922us/step - loss: 0.0015 - mean_absolute_error: 1.0572 - val_loss: 0.0011 - val_mean_absolute_error: 0.9876
# Epoch 19/50
# 384/384 [==============================] - 0s 1932us/step - loss: 0.0014 - mean_absolute_error: 1.0467 - val_loss: 0.0011 - val_mean_absolute_error: 1.0048
# Epoch 20/50
# 384/384 [==============================] - 0s 1930us/step - loss: 0.0014 - mean_absolute_error: 1.0395 - val_loss: 0.0011 - val_mean_absolute_error: 0.9852
# Epoch 21/50
# 384/384 [==============================] - 0s 1931us/step - loss: 0.0014 - mean_absolute_error: 1.0324 - val_loss: 0.0011 - val_mean_absolute_error: 0.9632
# Epoch 22/50
# 384/384 [==============================] - 0s 1933us/step - loss: 0.0014 - mean_absolute_error: 1.0256 - val_loss: 0.0010 - val_mean_absolute_error: 0.9527
# Epoch 23/50
# 384/384 [==============================] - 0s 1936us/step - loss: 0.0013 - mean_absolute_error: 1.0140 - val_loss: 0.0011 - val_mean_absolute_error: 1.0111
# Epoch 24/50
# 384/384 [==============================] - 0s 1923us/step - loss: 0.0013 - mean_absolute_error: 1.0102 - val_loss: 0.0011 - val_mean_absolute_error: 1.0090
# Epoch 25/50
# 384/384 [==============================] - 0s 1924us/step - loss: 0.0013 - mean_absolute_error: 1.0008 - val_loss: 0.0010 - val_mean_absolute_error: 0.9572
# Epoch 26/50
# 384/384 [==============================] - 0s 1935us/step - loss: 0.0013 - mean_absolute_error: 0.9949 - val_loss: 0.0010 - val_mean_absolute_error: 0.9417
# Epoch 27/50
# 384/384 [==============================] - 0s 1924us/step - loss: 0.0013 - mean_absolute_error: 0.9904 - val_loss: 0.0010 - val_mean_absolute_error: 0.9505
# Epoch 28/50
# 384/384 [==============================] - 0s 1937us/step - loss: 0.0013 - mean_absolute_error: 0.9831 - val_loss: 0.0010 - val_mean_absolute_error: 0.9168
# Epoch 29/50
# 384/384 [==============================] - 0s 1927us/step - loss: 0.0013 - mean_absolute_error: 0.9767 - val_loss: 0.0009 - val_mean_absolute_error: 0.9222
# Epoch 30/50
# 384/384 [==============================] - 0s 1944us/step - loss: 0.0012 - mean_absolute_error: 0.9712 - val_loss: 0.0010 - val_mean_absolute_error: 0.9382
# Epoch 31/50
# 384/384 [==============================] - 0s 1967us/step - loss: 0.0012 - mean_absolute_error: 0.9680 - val_loss: 0.0010 - val_mean_absolute_error: 0.9318
# Epoch 32/50
# 384/384 [==============================] - 0s 1932us/step - loss: 0.0012 - mean_absolute_error: 0.9625 - val_loss: 0.0009 - val_mean_absolute_error: 0.8972
# Epoch 33/50
# 384/384 [==============================] - 0s 1933us/step - loss: 0.0012 - mean_absolute_error: 0.9583 - val_loss: 0.0009 - val_mean_absolute_error: 0.9157
# Epoch 34/50
# 384/384 [==============================] - 0s 1931us/step - loss: 0.0012 - mean_absolute_error: 0.9539 - val_loss: 0.0009 - val_mean_absolute_error: 0.8886
# Epoch 35/50
# 384/384 [==============================] - 0s 1933us/step - loss: 0.0012 - mean_absolute_error: 0.9499 - val_loss: 0.0010 - val_mean_absolute_error: 0.9488
# Epoch 36/50
# 384/384 [==============================] - 0s 1935us/step - loss: 0.0012 - mean_absolute_error: 0.9487 - val_loss: 0.0009 - val_mean_absolute_error: 0.8885
# Epoch 37/50
# 384/384 [==============================] - 0s 1933us/step - loss: 0.0012 - mean_absolute_error: 0.9457 - val_loss: 0.0009 - val_mean_absolute_error: 0.9378

# %%
mo_wide_window.plot(mo_lstm_model)

# %%
mo_wide_window.plot(model=mo_lstm_model, plot_col='temp')

# %%
mo_mae_val.append(mo_val_performance['LSTM'][1])
mo_mae_test.append(mo_performance['LSTM'][1])

x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
    plt.text(x=index - 0.15, y=value+0.001, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mo_mae_test):
    plt.text(x=index + 0.15, y=value+0.001, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()
